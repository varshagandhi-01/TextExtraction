# %% [markdown]
# <a href="https://colab.research.google.com/github/varshagandhi-01/TextExtraction/blob/main/notebooks/text_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive

colab.drive.mount('/content/drive')

df = pd.read
